# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'datasets/cars.csv')

# %%
df.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0  M     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0  M     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1  M     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1  A     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0  A     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.shape
# Out:
# (32, 12)

# %%
df['name'].unique()
# Out:
# array(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D',
#        'Merc 230', 'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL',
#        'Merc 450SLC', 'Cadillac Fleetwood', 'Lincoln Continental',
#        'Chrysler Imperial', 'Fiat 128', 'Honda Civic', 'Toyota Corolla',
#        'Toyota Corona', 'Dodge Challenger', 'AMC Javelin', 'Camaro Z28',
#        'Pontiac Firebird', 'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa',
#        'Ford Pantera L', 'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype=object)

# %%
df['name'].nunique()
# Out:
# 32

# %%
df.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0  M     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0  M     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1  M     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1  A     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0  A     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df['am'].value_counts()
# Out:
# A    19
# M    13
# Name: am, dtype: int64

# %%
df['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
df['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
pd.crosstab(df['gear'], df['cyl'])
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
df = pd.read_csv(r'datasets/Employee_Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# df.isnull().sum()

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# df.dtypes

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include = 'O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.crosstab(df['BusinessTravel'], df['Department'])
# Out:
# Department         Human Resources  Research & Development  Sales
# BusinessTravel
# Non-Travel                       6                      97     47
# Travel_Frequently               11                     182     84
# Travel_Rarely                   46                     682    315

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'])
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'], normalize = True)*100
# Out:
# Attrition                 No        Yes
# BusinessTravel
# Non-Travel          9.387755   0.816327
# Travel_Frequently  14.149660   4.693878
# Travel_Rarely      60.340136  10.612245

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'], colnames = ['att'], rownames = ['travel'],normalize = True)*100
# Out:
# att                       No        Yes
# travel
# Non-Travel          9.387755   0.816327
# Travel_Frequently  14.149660   4.693878
# Travel_Rarely      60.340136  10.612245

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'])
# Out:
# Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
pd.crosstab(df['BusinessTravel'], df['Attrition'], values = df['DailyRate'], aggfunc = 'mean')
# Out:
# Attrition                  No         Yes
# BusinessTravel
# Non-Travel         814.355072  846.916667
# Travel_Frequently  823.865385  698.463768
# Travel_Rarely      809.552424  765.891026

# %%
# avergae hourlyrate across diff departments

# %%
df.groupby('Department')['HourlyRate'].mean()#.reset_index()
# Out:
# Department
# Human Resources           64.301587
# Research & Development    66.167534
# Sales                     65.520179
# Name: HourlyRate, dtype: float64

# %%
df.groupby('Department')['HourlyRate'].mean().reset_index()
# Out:
#                Department  HourlyRate
# 0         Human Resources   64.301587
# 1  Research & Development   66.167534
# 2                   Sales   65.520179

# %%
pd.pivot_table(df, index = ['Department'], values = ['HourlyRate'], aggfunc = 'mean')
# Out:
#                         HourlyRate
# Department
# Human Resources          64.301587
# Research & Development   66.167534
# Sales                    65.520179

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
pd.pivot_table(df, index = ['Department', 'BusinessTravel'], values = ['HourlyRate'], aggfunc = 'mean').reset_index()
# Out:
#                Department     BusinessTravel  HourlyRate
# 0         Human Resources         Non-Travel   57.333333
# 1         Human Resources  Travel_Frequently   66.272727
# 2         Human Resources      Travel_Rarely   64.739130
# 3  Research & Development         Non-Travel   64.927835
# 4  Research & Development  Travel_Frequently   65.247253
# 5  Research & Development      Travel_Rarely   66.589443
# 6                   Sales         Non-Travel   65.702128
# 7                   Sales  Travel_Frequently   64.619048
# 8                   Sales      Travel_Rarely   65.733333

# %%
df.groupby(['Department', 'BusinessTravel'])['HourlyRate'].mean().reset_index()
# Out:
#                Department     BusinessTravel  HourlyRate
# 0         Human Resources         Non-Travel   57.333333
# 1         Human Resources  Travel_Frequently   66.272727
# 2         Human Resources      Travel_Rarely   64.739130
# 3  Research & Development         Non-Travel   64.927835
# 4  Research & Development  Travel_Frequently   65.247253
# 5  Research & Development      Travel_Rarely   66.589443
# 6                   Sales         Non-Travel   65.702128
# 7                   Sales  Travel_Frequently   64.619048
# 8                   Sales      Travel_Rarely   65.733333

# %%
df.groupby(['Department', 'BusinessTravel']).agg({'HourlyRate':['sum', 'mean', 'count'], 'Age':['mean', 'sum']}).reset_index()
# Out:
#                Department     BusinessTravel HourlyRate                   \
#                                                     sum       mean count
# 0         Human Resources         Non-Travel        344  57.333333     6
# 1         Human Resources  Travel_Frequently        729  66.272727    11
# 2         Human Resources      Travel_Rarely       2978  64.739130    46
# 3  Research & Development         Non-Travel       6298  64.927835    97
# 4  Research & Development  Travel_Frequently      11875  65.247253   182
# 5  Research & Development      Travel_Rarely      45414  66.589443   682
# 6                   Sales         Non-Travel       3088  65.702128    47
# 7                   Sales  Travel_Frequently       5428  64.619048    84
# 8                   Sales      Travel_Rarely      20706  65.733333   315
#
#          Age
#         mean    sum
# 0  43.666667    262
# 1  34.636364    381
# 2  37.804348   1739
# 3  36.144330   3506
# 4  36.807692   6699
# 5  37.233138  25393
# ...
